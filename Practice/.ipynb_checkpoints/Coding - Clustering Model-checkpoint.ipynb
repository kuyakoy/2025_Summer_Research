# %%
# Following this K Means video
# https://www.youtube.com/watch?v=iNlZ3IU5Ffw&t=176s&ab_channel=AndyMcDonald
# my comment
import numpy as np
import seaborn as sns

# Libraries
import pandas as pd               # Read from .csv
import matplotlib.pyplot as plt   # Display results

# Modules
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
# Read in the dataset
dataset = pd.read_csv('/Users/joshuamarquez/anaconda_projects/2025_Summer_Research/Data Files/digital_behavior.csv')
dataset
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                    133.2          6.8         8.9           10.0
# 1                    109.5          5.5         9.4           10.0
# 2                     84.7          6.7         9.4            9.4
# 3                     88.9          6.0         9.4            5.1
# 4                     78.8          8.2         9.4            8.0
# ..                     ...          ...         ...            ...
# 495                   99.0          6.1         8.3           10.0
# 496                  148.8          7.5         9.1           10.0
# 497                  111.4          7.8        10.0           10.0
# 498                  134.6          8.0         9.3            4.0
# 499                   68.4          6.8         8.8            6.3
#
#      digital_wellbeing_score
# 0                       44.8
# 1                       43.6
# 2                       52.6
# 3                       58.4
# 4                       59.7
# ..                       ...
# 495                     42.4
# 496                     50.4
# 497                     49.5
# 498                     71.6
# 499                     56.5
#
# [500 rows x 9 columns]

# %%
# Drop any rows with NA (non-existent values)
df.dropna(inplace = True)
df
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                    133.2          6.8         8.9           10.0
# 1                    109.5          5.5         9.4           10.0
# 2                     84.7          6.7         9.4            9.4
# 3                     88.9          6.0         9.4            5.1
# 4                     78.8          8.2         9.4            8.0
# ..                     ...          ...         ...            ...
# 495                   99.0          6.1         8.3           10.0
# 496                  148.8          7.5         9.1           10.0
# 497                  111.4          7.8        10.0           10.0
# 498                  134.6          8.0         9.3            4.0
# 499                   68.4          6.8         8.8            6.3
#
#      digital_wellbeing_score
# 0                       44.8
# 1                       43.6
# 2                       52.6
# 3                       58.4
# 4                       59.7
# ..                       ...
# 495                     42.4
# 496                     50.4
# 497                     49.5
# 498                     71.6
# 499                     56.5
#
# [500 rows x 9 columns]

# %%
# Check if any duplicates in the dataset
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
# Drop any existing duplicates
dataset.drop_duplicates()
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                    133.2          6.8         8.9           10.0
# 1                    109.5          5.5         9.4           10.0
# 2                     84.7          6.7         9.4            9.4
# 3                     88.9          6.0         9.4            5.1
# 4                     78.8          8.2         9.4            8.0
# ..                     ...          ...         ...            ...
# 495                   99.0          6.1         8.3           10.0
# 496                  148.8          7.5         9.1           10.0
# 497                  111.4          7.8        10.0           10.0
# 498                  134.6          8.0         9.3            4.0
# 499                   68.4          6.8         8.8            6.3
#
#      digital_wellbeing_score
# 0                       44.8
# 1                       43.6
# 2                       52.6
# 3                       58.4
# 4                       59.7
# ..                       ...
# 495                     42.4
# 496                     50.4
# 497                     49.5
# 498                     71.6
# 499                     56.5
#
# [500 rows x 9 columns]

# %%
# Dataset has been cleaned, move on to clustering
# Slice the data into our two columns
# index 0 -> daily_screen_time_min
# index 1 -> sleep_hours

x = x = dataset[['social_media_time_min', 'sleep_hours']].values
x
# Out:
# array([[133.2,   5.9],
#        [109.5,   7.2],
#        [ 84.7,   8. ],
#        [ 88.9,   6.5],
#        [ 78.8,   6.9],
#        [ 82.6,   8.5],
#        [117. ,   6.8],
#        [ 87.8,   9.6],
#        [150.7,   7.2],
#        [186.9,   4.4],
#        [ 93.9,   7.4],
#        [130.8,   7. ],
#        [142.5,   8. ],
#        [141.2,   7.3],
#        [123.4,   6.3],
#        [153.4,   5. ],
#        [141.7,   6.2],
#        [ 64.3,   5.5],
#        [159.1,   5.8],
#        [159.9,   7.2],
#        [ 85.7,   8.5],
#        [121.7,   7. ],
#        [150.7,   5.1],
#        [110.6,   7. ],
#        [168.3,   7.9],
#        [226.4,   5.8],
#        [ 84.6,   6.3],
#        [ 57.9,   6.5],
#        [133.7,   5.6],
#        [152.5,   7.3],
#        [109.6,   6.4],
#        [185.4,   7. ],
#        [ 59.8,   5.4],
#        [151.2,   6. ],
#        [ 92.7,   7.4],
#        [197.4,   6.1],
#        [209.7,   8.6],
#        [ 85.5,   6. ],
#        [ 95.3,   6.8],
#        [158.7,   7.6],
#        [102.6,   4.8],
#        [118. ,   4.4],
#        [121.1,   4.7],
#        [ 33.6,   8. ],
#        [119.4,   5.8],
#        [ 89. ,   9.6],
#        [ 97.8,   5.8],
#        [185. ,   6.7],
#        [ 63.5,   8.4],
#        [156.6,   8.9],
#        [107.4,   9. ],
#        [107.4,   8. ],
#        [155.6,   7.7],
#        [135.3,   7.2],
#        [145.7,   7.4],
#        [163.6,   5.8],
#        [105.1,   5.5],
#        [ 92.4,   6.5],
#        [ 71.2,   6.3],
#        [ 82.9,   6. ],
#        [252.7,   7.3],
#        [176. ,   7.6],
#        [ 59.2,   6.6],
#        [ 60.5,   8.3],
#        [141.7,   5.1],
#        [144.6,   6.3],
#        [144.7,   5.6],
#        [108.5,   4.3],
#        [114.4,   6.4],
#        [134.8,   6.4],
#        [123.9,   8.3],
#        [ 30. ,   7.3],
#        [109.7,   5.3],
#        [ 81.7,   8.7],
#        [127.9,   8. ],
#        [254.3,   7.2],
#        [136.5,   6.2],
#        [105.9,   5.3],
#        [161.5,   6.1],
#        [141.7,   7.8],
#        [138.9,   8.8],
#        [147.3,   8.4],
#        [212.5,   5.9],
#        [ 69.1,   5.2],
#        [141.3,   6.7],
#        [ 78.3,   4.4],
#        [145. ,   6.9],
#        [ 78.7,   6.3],
#        [101.2,   5.9],
#        [106.7,   4.6],
#        [163.9,   7.1],
#        [161.3,   5.9],
#        [ 63.9,   5.1],
#        [122.5,   3.1],
#        [ 88.1,   6.5],
#        [ 63.4,   8.6],
#        [110.2,   8.5],
#        [106.1,   6. ],
#        [229.2,   5.8],
#        [139.5,   7.1],
#        [ 58. ,   5.3],
#        [ 94.6,   6.9],
#        [166. ,   7.4],
#        [214. ,   8. ],
#        [ 48.6,   6.4],
#        [ 35.4,   6.3],
#        [204.2,   5.4],
#        [137.5,   5.5],
#        [ 80.9,   6.2],
#        [144.1,   6.9],
#        [ 30. ,   7.6],
#        [120.2,   5.5],
#        [134.8,   8.3],
#        [161.6,   6.2],
#        [ 74.4,   6.5],
#        [123.9,   5.6],
#        [ 78.4,   3.6],
#        [131.5,   7.6],
#        [ 79.7,   7.4],
#        [101.6,   6.2],
#        [ 75.2,   6.6],
#        [149.3,   7.1],
#        [158.6,   4.6],
#        [109.4,   5.9],
#        [121.7,   7.5],
#        [ 54.8,   5. ],
#        [106.5,   6.9],
#        [117.7,   4.9],
#        [237.9,   7.1],
#        [ 70. ,   6.5],
#        [185.9,   4.6],
#        [164.9,   7.9],
#        [132.6,   5.6],
#        [199.1,   5.5],
#        [136.7,   6.7],
#        [137.5,   7.9],
#        [117.6,   5.3],
#        [175.1,   6.6],
#        [169.3,   7. ],
#        [ 91.8,   7.3],
#        [ 60.6,   6.7],
#        [110.9,   6.1],
#        [ 84. ,   5.5],
#        [117.1,   6.6],
#        [175.7,   5.2],
#        [ 99.4,   3. ],
#        [118.1,   7. ],
#        [122.6,   7.6],
#        [158.2,   3.7],
#        [ 30. ,   5.3],
#        [ 92.7,   7.2],
#        [129.5,   9. ],
#        [174. ,   6.5],
#        [ 97.9,   5.6],
#        [ 35.6,   6.3],
#        [147.9,   8.1],
#        [ 91.4,   5.7],
#        [ 66.5,   5.5],
#        [ 91.9,   5.9],
#        [111.7,   5.4],
#        [ 92.8,   6.6],
#        [ 30. ,   8.4],
#        [160.4,   6.9],
#        [177.4,   6.2],
#        [149.3,   6.1],
#        [ 68.8,   4.6],
#        [110.9,   7.6],
#        [119.7,   6.4],
#        [146.9,   6.3],
#        [150.1,  10. ],
#        [ 87. ,   6.9],
#        [123.7,   5.6],
#        [140.6,   6. ],
#        [185.5,   7.9],
#        [151.7,   6.6],
#        [155.5,   4.8],
#        [123.8,   7.6],
#        [183.5,   5.7],
#        [138.4,   8.7],
#        [ 81.3,   7.8],
#        [183.2,   6. ],
#        [151.4,   8. ],
#        [100.1,   6.6],
#        [ 98.4,   7.5],
#        [133.3,   7.1],
#        [140.8,   5.5],
#        [128.9,   5.7],
#        [134. ,   7.7],
#        [196.5,   6.1],
#        [168.2,   6. ],
#        [128.6,   5.4],
#        [162.4,   7. ],
#        [ 73.5,   9. ],
#        [137.9,   5.2],
#        [201.4,   6.5],
#        [110.2,   8.2],
#        [ 81.9,   6.4],
#        [ 90.7,   7. ],
#        [ 71. ,   5.2],
#        [ 84.7,   7. ],
#        [103.3,   6.3],
#        [ 56.7,   7.7],
#        [120.7,   7.9],
#        [160.6,   9.6],
#        [ 79.2,   7.2],
#        [188.4,   6.9],
#        [143. ,   6.7],
#        [166.4,   6.1],
#        [ 90.4,   6.9],
#        [158.5,   6.1],
#        [ 70.9,   6.7],
#        [160.1,   8.1],
#        [127.7,   5.3],
#        [144.9,   7.9],
#        [ 67.1,   8.1],
#        [ 79.7,   6.4],
#        [146.9,   4. ],
#        [ 77.3,   5.8],
#        [140.8,   8.1],
#        [ 58.5,   6.5],
#        [158.2,   5.3],
#        [ 64.5,   5.9],
#        [144.9,   7.5],
#        [148.2,   7.2],
#        [ 88.6,   6.2],
#        [146.2,   6.1],
#        [131.7,   6. ],
#        [ 95.8,   5.4],
#        [ 74.6,   8.4],
#        [ 31.7,   6.1],
#        [135.7,   8. ],
#        [ 49.6,   8.3],
#        [124.3,   7.7],
#        [108.1,   6. ],
#        [150.6,   7. ],
#        [106.4,   6.5],
#        [105.2,   5.4],
#        [152.9,   6.9],
#        [135.1,   5.1],
#        [134.2,   7.9],
#        [141.1,   5.9],
#        [ 50.9,   6.7],
#        [154.1,   6.8],
#        [147.6,   6.2],
#        [ 74.2,   7.2],
#        [109. ,   5.9],
#        [118.2,   7.5],
#        [113.9,   4.9],
#        [135. ,   6.7],
#        [184.4,   8.8],
#        [168.7,   5.3],
#        [ 61. ,   5.7],
#        [148. ,   7.1],
#        [179.8,   6.7],
#        [137.4,   6.9],
#        [169.1,   7.1],
#        [210.6,   7.3],
#        [166.1,   7.8],
#        [131.2,   7. ],
#        [167. ,   6.2],
#        [126.5,   7.3],
#        [121.1,   8.8],
#        [104.2,   6.3],
#        [190.4,   5.3],
#        [ 83.2,   7.8],
#        [189. ,   6.4],
#        [142.5,   3.9],
#        [ 57. ,   7.5],
#        [136.5,   5.9],
#        [ 30. ,   6.4],
#        [148.1,   6.9],
#        [159.8,   6.7],
#        [ 93.3,   7.4],
#        [125.6,   6. ],
#        [207.9,   7.1],
#        [ 97.2,   6.2],
#        [ 72.3,   7.4],
#        [186.7,   7.2],
#        [208.3,   5.4],
#        [120.2,   7.8],
#        [165.5,   5.9],
#        [180.4,   7.5],
#        [ 86.6,   6.9],
#        [ 98.2,   8.7],
#        [175.4,   6.2],
#        [195.8,   6.1],
#        [145.3,   6.5],
#        [ 80.4,   6.1],
#        [209.4,   7.5],
#        [ 96.1,   4.6],
#        [104.9,   5.2],
#        [135.4,   5.2],
#        [189.9,   7.6],
#        [158.4,   8.6],
#        [138.7,   6.4],
#        [140.8,   6.3],
#        [122. ,   6.6],
#        [145.1,   7.9],
#        [ 30. ,   5.4],
#        [106.7,   6.8],
#        [130.9,   7.7],
#        [ 68.2,   7.1],
#        [137.4,   6.7],
#        [110.8,   7.7],
#        [199. ,   3.3],
#        [190.8,   7.3],
#        [ 99. ,   5.7],
#        [113.2,   4.3],
#        [116.7,   7.1],
#        [ 99.7,   8.1],
#        [128.8,   6.3],
#        [ 85.9,   7.6],
#        [ 69.1,   8.4],
#        [148. ,   8.1],
#        [148.3,   8.5],
#        [ 83.8,   7.4],
#        [160.3,   6.6],
#        [ 91.6,   4.6],
#        [131.4,   6.2],
#        [156.9,   5.5],
#        [118.5,   9.1],
#        [140.5,   6.3],
#        [ 96.8,   6.6],
#        [111.2,   7.2],
#        [110.7,   6.6],
#        [ 86.4,   8.5],
#        [112. ,   5.8],
#        [ 50.3,   6.7],
#        [ 97.9,   5.6],
#        [107.2,   4.9],
#        [108.5,   5.8],
#        [109.1,   6.5],
#        [117.2,   6. ],
#        [141.6,   5.7],
#        [159.4,   4.8],
#        [ 90.8,   6.4],
#        [ 65.9,   4.7],
#        [ 73.1,   7.4],
#        [ 98.1,   6.6],
#        [104.2,   4.8],
#        [ 85.4,   6.1],
#        [ 61.7,   5.6],
#        [ 99.5,   6.9],
#        [128.2,   8.1],
#        [146.8,   4.2],
#        [ 94.9,   6.6],
#        [101.4,   6.3],
#        [ 78.3,   7.3],
#        [118.6,   6.8],
#        [ 81.8,   5.6],
#        [145.8,   6.1],
#        [ 39.6,   5.5],
#        [103.8,   7.8],
#        [133.5,   6.5],
#        [128.3,   8.8],
#        [241.2,   6.4],
#        [135.7,   5.6],
#        [ 74.8,   4.7],
#        [115.7,   4.3],
#        [ 40.1,   4.6],
#        [116.4,   6.8],
#        [ 82.5,   7.1],
#        [161.2,   4.6],
#        [ 95.3,   7.6],
#        [114.7,   5.9],
#        [ 91.4,   6.7],
#        [198.2,   8.4],
#        [105.5,   7.6],
#        [202.5,   6.2],
#        [156.6,   5.4],
#        [141.7,   3.9],
#        [136.6,   5.6],
#        [137.7,   6.2],
#        [ 33.3,   5.3],
#        [107.5,   6.3],
#        [158. ,   6.6],
#        [117.8,   6.2],
#        [ 56.8,   5.7],
#        [117.6,   6.7],
#        [196.7,   7. ],
#        [176.1,   5.2],
#        [117.2,   8.2],
#        [162.8,   6.4],
#        [103.5,   6.5],
#        [ 43.3,   7.3],
#        [ 78.4,   6.8],
#        [190.3,   7.6],
#        [107.7,   6.8],
#        [109. ,   5.8],
#        [106.5,   6.9],
#        [205.7,   5.1],
#        [193.2,   6.6],
#        [219.8,   6.5],
#        [112.8,   6.3],
#        [133.3,   6.3],
#        [ 51.8,   4.2],
#        [186.5,   5.8],
#        [ 67.4,   6.6],
#        [129.8,   6.7],
#        [ 70.6,   5.3],
#        [ 93.5,   8. ],
#        [ 82.3,   5.5],
#        [ 92.6,   7.7],
#        [ 95.7,   7. ],
#        [ 95.3,   5.7],
#        [157.5,   8.6],
#        [ 70.3,   5.1],
#        [129.9,   7.6],
#        [174.8,   7.7],
#        [ 96.9,   5.7],
#        [ 87.7,   8.2],
#        [109.6,   6.2],
#        [173.1,   6.8],
#        [128.7,   6.8],
#        [ 96.1,   6.3],
#        [141.8,   7.5],
#        [ 70.4,   7.5],
#        [150.7,   4.4],
#        [138.4,   8.1],
#        [106.1,   4.5],
#        [ 82.3,   7.7],
#        [ 80.1,   7.9],
#        [144.1,   5.2],
#        [175.3,   6. ],
#        [ 91.3,   5.2],
#        [140.6,   6.2],
#        [ 30. ,   6.1],
#        [ 93.7,   7.4],
#        [118.6,   8.1],
#        [ 79.1,   8.2],
#        [ 77.9,   5.8],
#        [ 89.9,   6.2],
#        [133.1,   4.5],
#        [111.6,   5.5],
#        [ 30. ,   7.7],
#        [ 30. ,   8.4],
#        [ 92.7,   5. ],
#        [140.6,   5.8],
#        [ 30. ,   6.5],
#        [ 97.5,   6.8],
#        [ 96.3,   5.5],
#        [182.5,   7. ],
#        [102.7,   5.9],
#        [137.2,   6.5],
#        [126.4,   7.2],
#        [ 30. ,   6.5],
#        [154.6,   6. ],
#        [129.7,   6.4],
#        [142.9,   6.4],
#        [296.7,   6.1],
#        [ 30. ,   6.2],
#        [197.6,   8.4],
#        [107.1,   7.2],
#        [132.9,   6.1],
#        [118. ,   7.3],
#        [100.9,   6.1],
#        [ 94.4,   7.9],
#        [134.8,   6.9],
#        [ 51.7,   6.4],
#        [153.8,   7. ],
#        [101.3,   4.6],
#        [ 69.1,   5.1],
#        [ 99.7,   5.1],
#        [176.6,   6.7],
#        [ 95.9,   8.6],
#        [136.1,   9.2],
#        [ 87.1,   7.3],
#        [154.1,   7.1],
#        [150.8,   4.3],
#        [203.2,   5.8],
#        [112.1,   5.6],
#        [150.1,   5.8],
#        [124.4,   6.3],
#        [178.3,   5.9],
#        [ 87.7,   4.1],
#        [153.5,   7.4],
#        [111.2,   5.2],
#        [117.1,   6.8],
#        [124.1,   9. ],
#        [131.4,   5.4],
#        [114.8,   3.5],
#        [129.7,   6.2],
#        [191. ,   7.8],
#        [164.3,   8.9],
#        [159.1,   5. ],
#        [ 99.5,   7.1],
#        [ 80. ,   5.9],
#        [163. ,   6.4],
#        [159.4,   9.7],
#        [186.3,   4.7],
#        [ 92.8,   6.8],
#        [109.7,   7.1],
#        [ 46.2,   7.8],
#        [102.3,   6.6],
#        [164.8,   6.9],
#        [ 99. ,   6. ],
#        [148.8,   6.8],
#        [111.4,   6.1],
#        [134.6,   7.2],
#        [ 68.4,   6.1]])

# %%
# Elbow method to find ideal number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
# Output wcss
wcss
# Out:
# [958423.4349999999,
#  340638.8659584155,
#  193331.98957207927,
#  108395.12759709728,
#  87447.95360641982,
#  58243.77925221046,
#  41195.74718550536,
#  30298.53967295854,
#  24384.125305292862,
#  19934.717276401007]

# %%
# Check Elbow Method graph
plt.plot(range(1, 11), wcss)

# %%
# 3 is the ideal number of clusters

# %%
# Output cluster assigned to each datum
kmeans = KMeans(n_clusters = 3, init = 'k-means++')
y_means = kmeans.fit_predict(x)
y_means
# Out:
# array([2, 2, 0, 0, 0, 0, 2, 0, 2, 1, 0, 2, 2, 2, 2, 2, 2, 0, 1, 1, 0, 2,
#        2, 2, 1, 1, 0, 0, 2, 2, 2, 1, 0, 2, 0, 1, 1, 0, 0, 1, 2, 2, 2, 0,
#        2, 0, 0, 1, 0, 1, 2, 2, 2, 2, 2, 1, 2, 0, 0, 0, 1, 1, 0, 0, 2, 2,
#        2, 2, 2, 2, 2, 0, 2, 0, 2, 1, 2, 2, 1, 2, 2, 2, 1, 0, 2, 0, 2, 0,
#        0, 2, 1, 1, 0, 2, 0, 0, 2, 2, 1, 2, 0, 0, 1, 1, 0, 0, 1, 2, 0, 2,
#        0, 2, 2, 1, 0, 2, 0, 2, 0, 0, 0, 2, 1, 2, 2, 0, 2, 2, 1, 0, 1, 1,
#        2, 1, 2, 2, 2, 1, 1, 0, 0, 2, 0, 2, 1, 0, 2, 2, 1, 0, 0, 2, 1, 0,
#        0, 2, 0, 0, 0, 2, 0, 0, 1, 1, 2, 0, 2, 2, 2, 2, 0, 2, 2, 1, 2, 2,
#        2, 1, 2, 0, 1, 2, 0, 0, 2, 2, 2, 2, 1, 1, 2, 1, 0, 2, 1, 2, 0, 0,
#        0, 0, 2, 0, 2, 1, 0, 1, 2, 1, 0, 1, 0, 1, 2, 2, 0, 0, 2, 0, 2, 0,
#        1, 0, 2, 2, 0, 2, 2, 0, 0, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 0, 2, 2, 2, 2, 1, 1, 0, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 2, 1,
#        0, 1, 2, 0, 2, 0, 2, 1, 0, 2, 1, 0, 0, 1, 1, 2, 1, 1, 0, 0, 1, 1,
#        2, 0, 1, 0, 2, 2, 1, 1, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 1, 1, 0, 2,
#        2, 0, 2, 0, 0, 2, 2, 0, 1, 0, 2, 1, 2, 2, 0, 2, 2, 0, 2, 0, 0, 2,
#        2, 2, 2, 2, 1, 0, 0, 0, 0, 2, 0, 0, 0, 2, 2, 0, 0, 0, 2, 0, 2, 0,
#        2, 2, 2, 1, 2, 0, 2, 0, 2, 0, 1, 0, 2, 0, 1, 2, 1, 1, 2, 2, 2, 0,
#        2, 1, 2, 0, 2, 1, 1, 2, 1, 2, 0, 0, 1, 2, 2, 2, 1, 1, 1, 2, 2, 0,
#        1, 0, 2, 0, 0, 0, 0, 0, 0, 1, 0, 2, 1, 0, 0, 2, 1, 2, 0, 2, 0, 2,
#        2, 2, 0, 0, 2, 1, 0, 2, 0, 0, 2, 0, 0, 0, 2, 2, 0, 0, 0, 2, 0, 0,
#        0, 1, 2, 2, 2, 0, 2, 2, 2, 1, 0, 1, 2, 2, 2, 0, 0, 2, 0, 2, 0, 0,
#        0, 1, 0, 2, 0, 2, 2, 1, 2, 2, 2, 1, 0, 2, 2, 2, 2, 2, 2, 2, 1, 1,
#        1, 0, 0, 1, 1, 1, 0, 2, 0, 2, 1, 0, 2, 2, 2, 0], dtype=int32)

# %%
# Concatenate cluster numbers to our original dataset

dataset = dataset.drop(columns=[col for col in dataset.columns if col == 'cluster'])
dataset = pd.concat([dataset, pd.DataFrame(y_means, columns=['cluster'])], axis = 1)
dataset
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                    133.2          6.8         8.9           10.0
# 1                    109.5          5.5         9.4           10.0
# 2                     84.7          6.7         9.4            9.4
# 3                     88.9          6.0         9.4            5.1
# 4                     78.8          8.2         9.4            8.0
# ..                     ...          ...         ...            ...
# 495                   99.0          6.1         8.3           10.0
# 496                  148.8          7.5         9.1           10.0
# 497                  111.4          7.8        10.0           10.0
# 498                  134.6          8.0         9.3            4.0
# 499                   68.4          6.8         8.8            6.3
#
#      digital_wellbeing_score  cluster
# 0                       44.8        2
# 1                       43.6        2
# 2                       52.6        0
# 3                       58.4        0
# 4                       59.7        0
# ..                       ...      ...
# 495                     42.4        0
# 496                     50.4        2
# 497                     49.5        2
# 498                     71.6        2
# 499                     56.5        0
#
# [500 rows x 10 columns]

# %%
# Create a scatterplot

# Set the cluster information
plt.scatter(x[dataset['cluster'] == 0, 0], x[dataset['cluster'] == 0, 1], s = 100, c = 'green', alpha = 0.2, 
            label = 'Generally low time, High sleep')
plt.scatter(x[dataset['cluster'] == 2, 0], x[dataset['cluster'] == 2, 1], s = 100, c = 'blue', alpha = 0.2, 
            label = 'Moderate time and sleep')
plt.scatter(x[dataset['cluster'] == 1, 0], x[dataset['cluster'] == 1, 1], s = 100, c = 'red', alpha = 0.2, 
            label = 'High time, Low sleep')

# Plot the graph
plt.xlabel('Social Media Time Daily (minutes)')
plt.ylabel('Sleep (hours)')
plt.legend()
plt.show()

# %%
# Set the average Behavioral Pattern score for each cluster
avg_scores = dataset.groupby('cluster')[['focus_score', 'mood_score', 'anxiety_level']].mean()
avg_scores_T = avg_scores.T

# %%
avg_scores_renamed = avg_scores.rename(columns=
{
    'focus_score': 'Focus',
    'mood_score': 'Mood',
    'anxiety_level': 'Anxiety'
})

# Clean up the plot
ax = avg_scores_renamed.plot(kind = 'bar', figsize = (8, 6))

xtick_labels = ['1 - Generally Healthy Users', '2 - Moderate Users', '3 - Generally Unhealthy Users']
colors = ['green', 'blue', 'red']

# Set the x-ticks and labels
ax.set_xticks(range(len(xtick_labels)))  # positions 0 1 and 2 
ax.set_xticklabels(xtick_labels, rotation = 0)

# Color each of the x-tick labels
for tick_label, color in zip(ax.get_xticklabels(), colors):
    tick_label.set_color(color)

plt.title('Cluster Profiles – Focus, Mood, Anxiety')
plt.ylabel('Average Score')
plt.xlabel('User Cluster')
plt.legend(title = 'Score Type')
plt.tight_layout()
plt.show()

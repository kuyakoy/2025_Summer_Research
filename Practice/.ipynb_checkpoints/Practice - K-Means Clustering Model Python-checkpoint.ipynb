# %%
# Now watching this video about K-Means clustering
# https://www.youtube.com/watch?v=bu60ZoMuS1Y&ab_channel=edureka%21

# Divides the entire data set into k clusters
# Requires:
# K = number of clusters
# Training set(m) = {x1, x2, x3...xm}

# Elbow method

# %%
import os
os.getcwd()
# Out:
# '/Users/joshuamarquez'

# %%
# Import the libraries to be able to import data --> do calculations --> visualize the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset =  pd.read_csv('/Users/joshuamarquez/anaconda_projects/Practice/digital_behavior.csv')
dataset
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
# ...

# %%
len(dataset)
# Out:
# 500

# %%
# .iloc[] slices the data when passing in an index
# Let's do sleep_hours (index 2) and social_media_time_min (index 4)
x = dataset.iloc[:,2:4].values
x
# Out:
# array([[  5.9,  89. ],
#        [  7.2,  79. ],
#        [  8. , 108. ],
#        [  6.5,  78. ],
#        [  6.9,  35. ],
#        [  8.5, 111. ],
#        [  6.8,  57. ],
#        [  9.6,  63. ],
#        [  7.2,  65. ],
#        [  4.4, 114. ],
#        [  7.4,  26. ],
#        [  7. , 158. ],
#        [  8. , 106. ],
#        [  7.3,  85. ],
#        [  6.3,  78. ],
#        [  5. ,  87. ],
#        [  6.2,  93. ],
#        [  5.5,  96. ],
#        [  5.8,  93. ],
#        [  7.2,  82. ],
#        [  8.5,  75. ],
#        [  7. ,  76. ],
#        [  5.1,  75. ],
#        [  7. , 108. ],
#        [  7.9,  94. ],
#        [  5.8,  20. ],
#        [  6.3,  96. ],
#        [  6.5,  84. ],
#        [  5.6,  79. ],
#        [  7.3,  70. ],
#        [  6.4, 108. ],
#        [  7. , 103. ],
#        [  5.4,  60. ],
#        [  6. ,  90. ],
#        [  7.4,  55. ],
#        [  6.1,  45. ],
#        [  8.6,  64. ],
#        [  6. , 101. ],
#        [  6.8, 103. ],
#        [  7.6,  92. ],
# ...

# %%
# SciKit learn is very interesting, powerful, and should check it out!
from sklearn.cluster import KMeans
wcss = []
for i in range (1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# Output
wcss
# Out:
# [287647.99062,
#  102445.26588170795,
#  54800.79578340648,
#  34036.69902180467,
#  24097.722976673824,
#  19085.336614915177,
#  13214.236142748041,
#  10815.523486433185,
#  9474.163673954903,
#  6931.507486317936]

# %%
plt.plot(range(1, 11), wcss)

# %%
# Here, from the graph above, the ideal number of clusters is when the y-value begins to level off
# So up until 4 clusters, the graph seems to be decreasing a lot
# But after 4, the data seems to be decreasing less and less
# Therefore, the ideal number of clusters is 4!

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++')
y_kmeans = kmeans.fit_predict(x)
y_kmeans
# This will output the cluster number each data point was assigned to, so COOOL!
# Out:
# array([2, 2, 1, 2, 3, 1, 0, 0, 0, 1, 3, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 0,
#        0, 1, 2, 3, 2, 2, 2, 0, 1, 1, 0, 2, 0, 3, 0, 2, 1, 2, 2, 2, 0, 2,
#        2, 2, 1, 2, 2, 1, 2, 0, 0, 0, 0, 0, 0, 0, 3, 2, 2, 0, 2, 1, 3, 0,
#        0, 0, 2, 0, 0, 3, 2, 3, 2, 2, 1, 3, 3, 2, 1, 1, 2, 0, 2, 0, 2, 2,
#        1, 1, 2, 0, 2, 3, 0, 0, 0, 2, 0, 1, 2, 2, 0, 2, 2, 0, 0, 0, 3, 0,
#        0, 2, 2, 2, 2, 0, 2, 0, 2, 0, 3, 0, 1, 1, 1, 1, 2, 2, 0, 0, 2, 1,
#        0, 0, 2, 2, 3, 3, 0, 3, 0, 0, 0, 1, 2, 2, 2, 3, 1, 2, 2, 3, 3, 2,
#        2, 0, 0, 1, 3, 1, 0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 0, 3, 0, 1, 2,
#        2, 0, 2, 2, 3, 1, 2, 2, 2, 2, 2, 2, 0, 0, 2, 1, 3, 3, 2, 2, 2, 2,
#        0, 1, 3, 0, 0, 3, 0, 1, 2, 2, 3, 0, 0, 0, 1, 2, 3, 2, 2, 1, 1, 0,
#        0, 3, 0, 2, 1, 2, 0, 2, 0, 1, 3, 2, 1, 2, 0, 0, 0, 1, 3, 1, 3, 0,
#        0, 2, 3, 2, 1, 3, 2, 0, 2, 2, 0, 2, 1, 0, 2, 3, 0, 2, 1, 2, 0, 2,
#        3, 2, 1, 0, 0, 2, 0, 2, 1, 0, 0, 0, 2, 0, 0, 1, 1, 0, 3, 1, 0, 2,
# ...

# %%
# 0 (Cluster 1): 218 times
# 1 (Cluster 2): 206 times
# 2 (Cluster 3): 101 times
# 3 (Cluster 4): 75 times

# %%
pd.concat([dataset, pd.DataFrame(y_kmeans)], axis = 1)
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
# ...

# %%
# Making a full dot plot, Color coding the clusters

# [y_kmeans == a, b]
# a = column index of data we are filtering?
# b = column index of data we are plotting?
# s = size
# c = color
# alpha = visibility

# We have 4 clusters, so we call the function ".scatter()" 4 times
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', alpha = 0.3)
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'orange', alpha = 0.3)
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'teal', alpha = 0.3)
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 100, c = 'blue', alpha = 0.3)

# %%
# This is really cool! I especially like K-Means clustering and understand it better now
# I can just think of the applications, maybe we can use it on focus and mood? Let's try that actually.
dataset
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
# ...

# %%
# Step 1: Check the data and find two good column indexes you want to compare
    # Let's choose focus_score (index 5) and anxiety_level (index 7)
    # and let's slice the data up
x2 = dataset.iloc[:,5:7].values
x2
# Out:
# array([[ 6.8,  8.9],
#        [ 5.5,  9.4],
#        [ 6.7,  9.4],
#        [ 6. ,  9.4],
#        [ 8.2,  9.4],
#        [ 7.4,  9.9],
#        [ 7.3,  9.2],
#        [ 7.6,  9.3],
#        [ 6.9, 10. ],
#        [ 7.2,  7.6],
#        [ 8.1,  8.5],
#        [ 6.1,  9.1],
#        [ 7.3,  8.9],
#        [ 6.8,  9.5],
#        [ 7.1,  8.2],
#        [ 6.8,  8. ],
#        [ 7. ,  8.9],
#        [ 6.2,  8.6],
#        [ 7.7,  8.8],
#        [ 7.2,  9.6],
#        [ 7. ,  9.4],
#        [ 6.7,  8.8],
#        [ 6.1,  9.1],
#        [ 7.2,  9.2],
#        [ 6.2,  9. ],
#        [ 7.3,  8.5],
#        [ 6.4,  9.1],
#        [ 8. ,  9.8],
#        [ 7.7,  9.4],
#        [ 7.4,  9.6],
#        [ 7.4,  8.5],
#        [ 6. ,  9.8],
#        [ 7.5,  8.6],
#        [ 7.2,  8.2],
#        [ 7.2,  9.2],
#        [ 8.1, 10. ],
#        [ 7.6,  8.9],
#        [ 7.4,  9.2],
#        [ 6. ,  9.4],
#        [ 6.3,  9.1],
#        [ 6.8,  8.4],
#        [ 6.8,  8.6],
#        [ 6.4,  9.3],
# ...

# %%
# Step 2: Pass in the sliced data and output a line graph to determine the ideal number of clusters
    # Declare Within Cluster Sum of Squares array = wcss2[]
    # Here, our data is x2, so we'll pass that in
wcss2 = []
for i in range (1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(x2)
    wcss2.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss2)

# %%
# Step 3: Now that we've found our ideal number of clusters (4)
# We'll store it in a y_means variable
    # kmeans2
    # y_means2
    # x2

kmeans2 = KMeans(n_clusters = 4, init = 'k-means++')
y_kmeans2 = kmeans2.fit_predict(x2)
y_kmeans2
# Out:
# array([1, 0, 1, 0, 2, 2, 2, 2, 1, 3, 2, 0, 2, 1, 3, 3, 1, 0, 2, 1, 1, 1,
#        0, 1, 0, 3, 0, 2, 2, 2, 3, 0, 3, 3, 1, 2, 2, 2, 0, 0, 3, 3, 1, 2,
#        2, 2, 1, 1, 0, 3, 3, 1, 2, 1, 0, 0, 2, 2, 2, 0, 3, 0, 2, 1, 3, 2,
#        3, 1, 0, 2, 0, 0, 3, 1, 2, 1, 1, 3, 1, 1, 1, 3, 1, 1, 0, 3, 1, 1,
#        3, 0, 3, 1, 1, 2, 2, 3, 3, 1, 3, 0, 2, 3, 2, 3, 0, 1, 3, 3, 2, 1,
#        2, 1, 0, 0, 1, 1, 1, 3, 0, 2, 2, 3, 0, 3, 0, 3, 3, 2, 1, 2, 2, 1,
#        2, 1, 3, 3, 3, 1, 3, 2, 1, 1, 0, 1, 0, 3, 3, 2, 0, 2, 2, 2, 3, 2,
#        1, 2, 3, 2, 3, 1, 1, 3, 1, 0, 0, 1, 1, 0, 3, 3, 1, 1, 3, 3, 0, 0,
#        2, 1, 3, 1, 0, 3, 1, 1, 3, 1, 0, 3, 3, 2, 2, 0, 2, 3, 2, 0, 1, 1,
#        1, 1, 1, 1, 3, 1, 2, 0, 0, 1, 0, 0, 0, 1, 3, 3, 1, 1, 3, 0, 0, 1,
#        0, 2, 1, 3, 0, 3, 1, 3, 1, 0, 1, 1, 3, 2, 1, 1, 1, 0, 3, 1, 3, 2,
#        3, 2, 2, 3, 3, 3, 0, 0, 2, 0, 3, 1, 3, 3, 1, 2, 1, 0, 0, 3, 2, 3,
#        2, 1, 2, 2, 3, 2, 3, 3, 0, 2, 3, 3, 2, 2, 2, 0, 0, 3, 2, 1, 3, 0,
# ...

# %%
# Step 4: Concatenate the k-means assigned cluster values to the end of our original data set
pd.concat([dataset, pd.DataFrame(y_kmeans2)], axis = 1)
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
# ...

# %%
# Step 5: Making a full dot plot! And color code the clusters!

# [y_kmeans == a, b]
# a = column index of data we are filtering?
# b = column index of data we are plotting?
# s = size
# c = color
# alpha = visibility

# We have 4 clusters, so we call the function ".scatter()" 4 times
plt.scatter(x2[y_kmeans2 == 0, 0], x2[y_kmeans2 == 0, 1], s = 100, c = 'red', alpha = 0.3)
plt.scatter(x2[y_kmeans2 == 1, 0], x2[y_kmeans2 == 1, 1], s = 100, c = 'orange', alpha = 0.3)
plt.scatter(x2[y_kmeans2 == 2, 0], x2[y_kmeans2 == 2, 1], s = 100, c = 'teal', alpha = 0.3)
plt.scatter(x2[y_kmeans2 == 3, 0], x2[y_kmeans2 == 3, 1], s = 100, c = 'blue', alpha = 0.3)
plt.xlabel('Focus Score (larger value = more focused)')
plt.ylabel('Anxiety Level (larger value = more anxious)')
# Out:
# Text(0, 0.5, 'Anxiety Level (larger value = more anxious)')

# %%
# WWOWW it actually worked, nice!
